# %%
import pandas as pd

# %%
df = pd.read_csv("반도체_공정데이터_전체.csv")

# %%
df.shape
# Out:
# (728, 31)

# %%
df.head()
# Out:
#    etch_chamber_temp_avg  cmp_endpoint_thickness  thermal_anneal_temp_max  \
# 0                 2.2300                 17.7700                  10.1066
# 1                 0.8764                     NaN                   4.9259
# 2                27.4627                 12.5373                   5.4171
# 3                -2.8555                 22.8555                   6.7199
# 4                -2.0836                 22.0836                  13.9342
#
#    etch_endpoint_signal  wafer_edge_exclusion  etch_pressure_peak  \
# 0               66.4333               57.6641            -5333.75
# 1               69.3333              902.0772                0.00
# 2               72.8222              529.3532            -6312.25
# 3                   NaN                0.0000            -6476.25
# 4                   NaN              229.3217                 NaN
#
#    cmp_pad_temp  deposition_uniformity_index  deposition_thickness_var  \
# 0       11.3429                       0.0492                       NaN
# 1        0.0000                       0.0000                    8.7696
# 2        7.6993                       0.0460                    9.3998
# 3           NaN                       0.0344                       NaN
# 4        6.4235                       0.0466                    8.7568
#
#    cleaning_dhf_concentration  ...  cmp_polish_time  litho_exposure_time  \
# 0                      1.8000  ...           4.1872                0.103
# 1                      3.3099  ...           0.0000                0.000
# 2                      3.2042  ...           4.3765                0.112
# 3                      2.0083  ...           2.8420                0.080
# 4                      3.8979  ...              NaN                0.100
#
#    deposition_chamber_pressure  litho_dose_avg  implant_tilt_angle  \
# 0                       0.0755          0.0295              5.3530
# 1                       0.1004          0.0295              6.5683
# 2                       0.2177          0.0315              5.8049
# 3                       0.0956          0.0295              5.6773
# 4                          NaN          0.0123                 NaN
#
#    implant_energy_mean  cmp_pressure_avg  particle_count_post  \
# 0               1.7350             15.65             221.4286
# 1               0.9791             15.93              52.4656
# 2               1.3800             15.88             410.1695
# 3               1.1020             15.47             767.4074
# 4               0.9838             15.95             134.6375
#
#    litho_focus_offset  inspection_result
# 0             -0.0085               Pass
# 1             -0.0110               Pass
# 2             -0.0100               Pass
# 3             -0.0109               Pass
# 4             -0.0104               Pass
#
# [5 rows x 31 columns]

# %%
y = df['inspection_result']
X = df.drop('inspection_result', axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train, y_train
# Out:
# (     etch_chamber_temp_avg  cmp_endpoint_thickness  thermal_anneal_temp_max  \
#  163                -0.9364                 20.9364                   7.1584
#  270                 7.0709                 12.9291                  11.8500
#  274                    NaN                 22.6982                  16.0500
#  8                  -0.3736                     NaN                   8.0610
#  559                 4.4827                 15.5173                  12.6090
#  ..                     ...                     ...                      ...
#  91                 -1.5118                 21.5118                   8.2631
#  334                -8.2255                 28.2255                  14.9117
#  573                25.4300                 14.5700                      NaN
#  679               -10.6036                 30.6036                  14.6661
#  488                10.0800                 29.9200                  13.0319
#
#       etch_endpoint_signal  wafer_edge_exclusion  etch_pressure_peak  \
#  163               71.8000              319.5980            -5977.25
#  270               70.6444                   NaN            -6626.50
#  274               63.0000                0.0000            -6235.25
#  8                 68.7667                0.0000            -5135.00
#  559               69.4778              990.0552            -6249.25
#  ..                    ...                   ...                 ...
#  91                68.9778                   NaN            -6225.75
#  334               66.0889              756.5217            -5393.25
#  573               68.9000                0.0000            -6308.50
#  679               65.5000              369.9422            -6402.75
#  488               61.8778                0.0000            -5418.25
#
#       cmp_pad_temp  deposition_uniformity_index  deposition_thickness_var  \
#  163       15.4753                       0.0816                    8.5851
#  270        6.0364                       0.0484                    8.7851
#  274       48.5466                          NaN                    9.2405
#  8         11.0808                       0.0536                    8.9635
#  559        9.0251                       0.0446                    8.5855
#  ..            ...                          ...                       ...
#  91        11.1794                       0.0483                    8.6439
#  334        9.8456                       0.0813                    8.8249
#  573        7.6722                       0.0447                    8.8287
#  679        5.7007                       0.0475                    8.5405
#  488       20.8924                       0.0470                    9.0998
#
#       cleaning_dhf_concentration  ...  etch_rf_power_mean  cmp_polish_time  \
#  163                      2.8249  ...             -2.2220           6.5623
#  270                      4.2481  ...                 NaN           3.4639
#  274                      3.5045  ...              0.0946           5.1681
#  8                        4.1570  ...             -1.6550           6.4484
#  559                      2.7918  ...                 NaN           5.3609
#  ..                          ...  ...                 ...              ...
#  91                       4.1436  ...             -0.7096           3.9804
#  334                      4.7121  ...                 NaN           2.4657
#  573                         NaN  ...                 NaN           3.8035
#  679                         NaN  ...              0.2838           5.0385
#  488                      7.0265  ...              0.6623           4.2629
#
#       litho_exposure_time  deposition_chamber_pressure  litho_dose_avg  \
#  163                0.189                       0.0703          0.0295
#  270                0.108                       0.0678          0.0515
#  274                0.173                       0.0449          0.1614
#  8                  0.123                       0.0487          0.0147
#  559                0.108                       0.0555          0.0115
#  ..                   ...                          ...             ...
#  91                 0.117                       0.0890          0.0195
#  334                0.194                       0.0462          0.0295
#  573                0.102                       0.0591          0.0878
#  679                0.108                       0.0736          0.0510
#  488                0.101                       0.1399          0.0337
#
#       implant_tilt_angle  implant_energy_mean  cmp_pressure_avg  \
#  163              6.5571               0.9602             15.73
#  270              5.4252               1.4180             15.99
#  274                 NaN               1.0210             15.68
#  8                5.2192                  NaN             15.95
#  559                 NaN               0.9365             15.87
#  ..                  ...                  ...               ...
#  91               5.7194               1.1350             15.91
#  334              4.7156                  NaN               NaN
#  573              5.6444               1.0020             15.83
#  679              6.4455               1.3140               NaN
#  488              4.9691               0.9176             15.80
#
#       particle_count_post  litho_focus_offset
#  163              56.9813             -0.0158
#  270             109.4629             -0.0118
#  274             231.5197             -0.0057
#  8               229.6029             -0.0107
#  559                  NaN             -0.0092
#  ..                   ...                 ...
#  91              437.8601             -0.0068
#  334             181.2746             -0.0053
#  573             211.7040             -0.0067
#  679              86.7314             -0.0089
#  488             168.1682             -0.0040
#
#  [582 rows x 30 columns],
#  163    Pass
#  270    Pass
#  274    Pass
#  8      Pass
#  559    Pass
#         ...
#  91     Pass
#  334    Pass
#  573    Pass
#  679    Pass
#  488    Pass
#  Name: inspection_result, Length: 582, dtype: str)

# %%
X_train2 = pd.concat([X_train, y_train], axis=1).reset_index(drop=True)

# %%
X_train2.to_csv("X_train.csv", index=False)

# %%
X_test.to_csv("X_test.csv", index=False)
y_test.to_csv("y_test.csv", index=False)
